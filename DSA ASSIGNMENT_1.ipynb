# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
iris=pd.read_excel('iris.xls')

# %%
iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
iris.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
iris.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
plt.plot(iris.SL)
plt.plot(iris.SW)
plt.plot(iris.PL)
plt.plot(iris.PW)
plt.grid(True,color='k')

# %%
plt.figure()
plt.hist(iris['SL'],color='black',rwidth=0.5,density='true')
plt.title('SL barchart',fontsize=12)
plt.xticks()
plt.yticks()
plt.figure()
plt.hist(iris['SW'],color='green',rwidth=0.5,density='true')
plt.title('SW barchart',fontsize=12)
plt.xticks()
plt.yticks()
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
iris[['SW','SL','PW','PL']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris[['SW','SL','PW','PL']].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
